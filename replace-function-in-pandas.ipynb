# %% [markdown]
# <a href="https://www.kaggle.com/code/avisonstevedsouza/replace-function-in-pandas?scriptVersionId=201027060" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/kaggle/input/sampledata/sample.csv')
df.head()
# Out:
#    Roll No.  Physics  Chemistry  Maths  Computer
# 0         1     56.0       57.0   58.0      59.0
# 1         2     23.0       24.0   25.0      26.0
# 2         3     89.0       25.0   26.0      27.0
# 3         4     45.0       26.0   27.0      28.0
# 4         5     23.0       27.0   28.0      29.0

# %%
df
# Out:
#     Roll No.  Physics  Chemistry  Maths  Computer
# 0          1     56.0       57.0   58.0      59.0
# 1          2     23.0       24.0   25.0      26.0
# 2          3     89.0       25.0   26.0      27.0
# 3          4     45.0       26.0   27.0      28.0
# 4          5     23.0       27.0   28.0      29.0
# 5          6     90.0        NaN   29.0      30.0
# 6          7     12.0       13.0   14.0      15.0
# 7          8     78.0       14.0   15.0      16.0
# 8          9      NaN       15.0   16.0      17.0
# 9         10     45.0       16.0   17.0      18.0
# 10        11      NaN       17.0   18.0      19.0
# 11        12     88.0        NaN   19.0      20.0
# 12        13     22.0       23.0   24.0      25.0
# 13        14     90.0        NaN    NaN      42.0
# 14        15      NaN       43.0   43.0      43.0
# 15        16     44.0       44.0   44.0      44.0
# 16        17     45.0       45.0   45.0      45.0
# 17        18     46.0       46.0   46.0      46.0
# ...

# %% [markdown]
# # Replace

# %%
df.fillna(method='ffill',inplace=True)
# Out:
# /tmp/ipykernel_17/4116506308.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',inplace=True)

# %%
df
# Out:
#     Roll No.  Physics  Chemistry  Maths  Computer
# 0          1     56.0       57.0   58.0      59.0
# 1          2     23.0       24.0   25.0      26.0
# 2          3     89.0       25.0   26.0      27.0
# 3          4     45.0       26.0   27.0      28.0
# 4          5     23.0       27.0   28.0      29.0
# 5          6     90.0       27.0   29.0      30.0
# 6          7     12.0       13.0   14.0      15.0
# 7          8     78.0       14.0   15.0      16.0
# 8          9     78.0       15.0   16.0      17.0
# 9         10     45.0       16.0   17.0      18.0
# 10        11     45.0       17.0   18.0      19.0
# 11        12     88.0       17.0   19.0      20.0
# 12        13     22.0       23.0   24.0      25.0
# 13        14     90.0       23.0   24.0      42.0
# 14        15     90.0       43.0   43.0      43.0
# 15        16     44.0       44.0   44.0      44.0
# 16        17     45.0       45.0   45.0      45.0
# 17        18     46.0       46.0   46.0      46.0
# ...

# %%
df.head()
# Out:
#    Roll No.  Physics  Chemistry  Maths  Computer
# 0         1     56.0       57.0   58.0      59.0
# 1         2     23.0       24.0   25.0      26.0
# 2         3     89.0       25.0   26.0      27.0
# 3         4     45.0       26.0   27.0      28.0
# 4         5     23.0       27.0   28.0      29.0

# %%
df.replace(to_replace=26,value=30)
# Out:
#     Roll No.  Physics  Chemistry  Maths  Computer
# 0          1     56.0       57.0   58.0      59.0
# 1          2     23.0       24.0   25.0      30.0
# 2          3     89.0       25.0   30.0      27.0
# 3          4     45.0       30.0   27.0      28.0
# 4          5     23.0       27.0   28.0      29.0
# 5          6     90.0       27.0   29.0      30.0
# 6          7     12.0       13.0   14.0      15.0
# 7          8     78.0       14.0   15.0      16.0
# 8          9     78.0       15.0   16.0      17.0
# 9         10     45.0       16.0   17.0      18.0
# 10        11     45.0       17.0   18.0      19.0
# 11        12     88.0       17.0   19.0      20.0
# 12        13     22.0       23.0   24.0      25.0
# 13        14     90.0       23.0   24.0      42.0
# 14        15     90.0       43.0   43.0      43.0
# 15        16     44.0       44.0   44.0      44.0
# 16        17     45.0       45.0   45.0      45.0
# 17        18     46.0       46.0   46.0      46.0
# ...

# %%
df.replace(56,60)
# Out:
#     Roll No.  Physics  Chemistry  Maths  Computer
# 0          1     60.0       57.0   58.0      59.0
# 1          2     23.0       24.0   25.0      26.0
# 2          3     89.0       25.0   26.0      27.0
# 3          4     45.0       26.0   27.0      28.0
# 4          5     23.0       27.0   28.0      29.0
# 5          6     90.0       27.0   29.0      30.0
# 6          7     12.0       13.0   14.0      15.0
# 7          8     78.0       14.0   15.0      16.0
# 8          9     78.0       15.0   16.0      17.0
# 9         10     45.0       16.0   17.0      18.0
# 10        11     45.0       17.0   18.0      19.0
# 11        12     88.0       17.0   19.0      20.0
# 12        13     22.0       23.0   24.0      25.0
# 13        14     90.0       23.0   24.0      42.0
# 14        15     90.0       43.0   43.0      43.0
# 15        16     44.0       44.0   44.0      44.0
# 16        17     45.0       45.0   45.0      45.0
# 17        18     46.0       46.0   46.0      46.0
# ...

# %%
df.replace(to_replace=[56,60,57,58,59],value='A')
# Out:
#     Roll No. Physics Chemistry Maths Computer
# 0          1       A         A     A        A
# 1          2    23.0      24.0  25.0     26.0
# 2          3    89.0      25.0  26.0     27.0
# 3          4    45.0      26.0  27.0     28.0
# 4          5    23.0      27.0  28.0     29.0
# 5          6    90.0      27.0  29.0     30.0
# 6          7    12.0      13.0  14.0     15.0
# 7          8    78.0      14.0  15.0     16.0
# 8          9    78.0      15.0  16.0     17.0
# 9         10    45.0      16.0  17.0     18.0
# 10        11    45.0      17.0  18.0     19.0
# 11        12    88.0      17.0  19.0     20.0
# 12        13    22.0      23.0  24.0     25.0
# 13        14    90.0      23.0  24.0     42.0
# 14        15    90.0      43.0  43.0     43.0
# 15        16    44.0      44.0  44.0     44.0
# 16        17    45.0      45.0  45.0     45.0
# 17        18    46.0      46.0  46.0     46.0
# 18        19    47.0      47.0  47.0     47.0
# ...

# %%
df.replace(to_replace=[23,24,25,26],value=['B','C','D','E'],inplace=True)

# %%
df['Physics'].replace(to_replace=[27,28,29,20],value=['B','C','D','E'])
# Out:
# 0     56.0
# 1        B
# 2     89.0
# 3     45.0
# 4        B
# 5     90.0
# 6     12.0
# 7     78.0
# 8     78.0
# 9     45.0
# 10    45.0
# 11    88.0
# 12    22.0
# 13    90.0
# 14    90.0
# 15    44.0
# 16    45.0
# 17    46.0
# 18    47.0
# 19    48.0
# 20    49.0
# 21    50.0
# 22    51.0
# 23    52.0
# 24    53.0
# 25    54.0
# 26    55.0
# 27    56.0
# 28    57.0
# 29    58.0
# Name: Physics, dtype: object

# %%
df.replace('[A-Za-z]',0,regex=True,inplace=True)
# Out:
# /tmp/ipykernel_17/4282710532.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace('[A-Za-z]',0,regex=True,inplace=True)

# %%
df
# Out:
#     Roll No.  Physics  Chemistry  Maths  Computer
# 0          1     56.0       57.0   58.0      59.0
# 1          2      0.0        0.0    0.0       0.0
# 2          3     89.0        0.0    0.0      27.0
# 3          4     45.0        0.0   27.0      28.0
# 4          5      0.0       27.0   28.0      29.0
# 5          6     90.0       27.0   29.0      30.0
# 6          7     12.0       13.0   14.0      15.0
# 7          8     78.0       14.0   15.0      16.0
# 8          9     78.0       15.0   16.0      17.0
# 9         10     45.0       16.0   17.0      18.0
# 10        11     45.0       17.0   18.0      19.0
# 11        12     88.0       17.0   19.0      20.0
# 12        13     22.0        0.0    0.0       0.0
# 13        14     90.0        0.0    0.0      42.0
# 14        15     90.0       43.0   43.0      43.0
# 15        16     44.0       44.0   44.0      44.0
# 16        17     45.0       45.0   45.0      45.0
# 17        18     46.0       46.0   46.0      46.0
# ...

# %%
df.replace(to_replace=50,method='ffill',inplace=True)
# Out:
# /tmp/ipykernel_17/4047435203.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   df.replace(to_replace=50,method='ffill',inplace=True)

# %%
df.replace(to_replace=51,method='bfill')
# Out:
# /tmp/ipykernel_17/3036359123.py:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   df.replace(to_replace=51,method='bfill')
#     Roll No.  Physics  Chemistry  Maths  Computer
# 0          1     56.0       57.0   58.0      59.0
# 1          2      0.0        0.0    0.0       0.0
# 2          3     89.0        0.0    0.0      27.0
# 3          4     45.0        0.0   27.0      28.0
# 4          5      0.0       27.0   28.0      29.0
# 5          6     90.0       27.0   29.0      30.0
# 6          7     12.0       13.0   14.0      15.0
# 7          8     78.0       14.0   15.0      16.0
# 8          9     78.0       15.0   16.0      17.0
# 9         10     45.0       16.0   17.0      18.0
# 10        11     45.0       17.0   18.0      19.0
# 11        12     88.0       17.0   19.0      20.0
# 12        13     22.0        0.0    0.0       0.0
# 13        14     90.0        0.0    0.0      42.0
# ...

# %% [markdown]
# ***End***
